# %%
import saspy
import os
import pandas as pd
import numpy as np
from IPython.core.display import display, HTML

# %%
# Provide the path to your configuration file
sas = saspy.SASsession(cfgfile='saspy_config.py')
# Out:
# Using SAS Config named: oda
# Did not find key oda in authinfo file:/Users/zheyujiang/.authinfo
#
# Please enter the OMR user id: zheyujiang@gmail.com
# Please enter the password for OMR user : ········
# SAS Connection established. Subprocess id is 33510

# %%
# read in working data for modeling
# acs = pd.read_csv("Data/Output Data/acs_for_model_20240607_2907.csv")

# %%
sas_code = """
libname scmodel '/home/zheyujiang0/SC';
proc import file = "/home/zheyujiang0/SC/acs_for_model_20240607_2907.csv" out = acs replace;
run;

# %inc "/home/zheyujiang0/SC/PROC FORMAT.sas";
data scmodel.acs_20240607;
    set acs;
    # %inc "/home/zheyujiang0/SC/FORMAT.sas";
run;

ods exclude all;
ods output oneway = freq;
proc surveyfreq data = scmodel.acs_20240607 (drop = sc_age_cont);
table sc_:;
weight PWGTP;
run;
ods exclude none;

proc contents data = freq;
run;

data freq2;
	set freq;
	keep variable category frequency WgtFreq Percent;
    
    array cat_array{*} $ F_sc_:;
    
    do i = 1 to dim(cat_array);
        if not missing(cat_array[i]) then do;
            category = cat_array[i];
        end;
    end;
	variable = scan(Table, 2, " ");
	if _SkipLine ne "1";
run;


proc sort data = freq2;
	by variable category;
run;

ods excel file = "/home/zheyujiang0/SC/acs_freq.xlsx";
proc report data = freq2;
    column 	variable	category Frequency	WgtFreq	Percent;
    define variable /display "Variable";
    define category /display "Category";
    define Frequency /display "Raw Frequency" format = comma10.;
    define WgtFreq/display "Population" f = comma10.;
    define percent/display "Percent" f = 6.2;
run;
ods excel close;

"""

result = sas.submit(sas_code)
# print(result['LOG'])

# %%
display(HTML(result['LST']))
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...
